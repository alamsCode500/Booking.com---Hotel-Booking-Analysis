# %% [markdown]
# # **Project Name**    - **Booking.com - Hotel Booking Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary - Booking.com - Hotel Booking Analysis**

# %% [markdown]
# This project aimed to analyze a comprehensive dataset of hotel bookings to derive actionable insights that could help the hotel business improve its operations, reduce cancellations, increase revenue, and enhance customer satisfaction. By analyzing various factors such as booking lead time, customer type, market segment, special requests, and cancellation patterns, we sought to identify key trends and correlations that impact the hotel’s business performance.
#
# **Key Steps in the Project:**
#
# **Data Exploration & Cleaning:**
#
# * The dataset included a wide range of variables, including customer details, booking status, special requests, and hotel features. Initial data cleaning and exploration helped identify any missing or inconsistent data, ensuring that the analysis was based on clean, reliable information.
#
# **Descriptive Analysis:**
#
# * We explored the distribution of key variables such as lead time, average daily rate (ADR), number of special requests, and the cancellation rate. This gave us an understanding of the overall trends and patterns in the dataset, such as the most common booking behaviors, seasonality effects, and the impact of special requests on bookings.
#
# **Bivariate & Multivariate Analysis:**
#
# * Through visualizations like histograms, scatter plots, bar plots, and box plots, we analyzed relationships between key variables. For example, we looked at how lead time and cancellation rate were correlated, how customer type affected ADR, and how special requests varied across hotel types and cancellation status.
#
# **Insights Derived:**
#
# * **High Cancellation Rates:** A significant portion of cancellations were linked to long lead times and certain customer types. Identifying these patterns allowed us to suggest strategies for reducing cancellations, such as offering flexible yet non-refundable options for specific customer segments.
#
# * **Revenue Optimization:** We found that the average daily rate (ADR) was influenced by both booking lead time and hotel type. By optimizing pricing strategies based on demand forecasting and adjusting for seasonality, the hotel could increase ADR and profitability.
#
# * **Customer Segmentation:** Different customer types (e.g., repeat guests, corporate guests) exhibited distinct behaviors. Tailored offerings and loyalty programs could increase retention and bookings from these segments.
#
# * **Operational Efficiency:** We identified peak and off-peak periods based on booking and cancellation data, allowing the hotel to adjust staffing, room allocation, and special requests management to enhance overall efficiency.
#
# **Recommendations:**
#
# * **Pricing Strategies:** Implement dynamic pricing based on booking lead time, seasonality, and customer type.
#
# * **Loyalty Programs:** Target repeat guests with customized offers to increase retention and reduce cancellations.
#
# * **Operational Adjustments:** Improve resource management during peak seasons and reduce wasteful overstaffing during low-demand periods.
#
# * **Cancellation Reduction:** Offer more attractive policies for long-lead bookings to minimize cancellations.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/alamsCode500/Hotel_Booking_Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# * **High Cancellation Rate:** Understanding the primary factors contributing to high cancellation rates and how they can be reduced, particularly for customers with different lead times, booking types, and customer segments.
#
# * **Revenue Maximization:** Investigating how factors such as the Average Daily Rate (ADR), lead time, hotel type, and special requests impact revenue, and how to adjust pricing strategies for better profitability without losing competitive advantage.
#
# * **Customer Segmentation:** Identifying patterns in customer booking behaviors based on variables like customer type, market segment, and special requests to better target and tailor offers for different customer groups.
#
# * **Operational Efficiency:** Identifying operational bottlenecks or inefficiencies (such as overbooking, low occupancy during off-peak periods) and proposing solutions based on booking and guest behavior patterns.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# **Reduce Cancellation Rate:**
#
# * Identify the key factors contributing to cancellations (e.g., lead time, customer type, booking channels) and implement strategies to reduce the cancellation rate, such as offering non-refundable rates for long-lead bookings, targeting loyal customers, and adjusting policies based on booking behavior.
#
# **Maximize Average Daily Rate (ADR):**
#
# * Utilize customer segmentation and booking patterns to optimize pricing strategies, increasing ADR without sacrificing demand. Implement dynamic pricing based on customer profiles, booking lead time, and seasonality to ensure competitive but profitable pricing.
#
# **Increase Customer Retention and Loyalty:**
#
# * Focus on building loyalty programs for repeat customers and improve the guest experience by accommodating special requests. Tailor marketing strategies to engage different customer segments and enhance personalized offerings.
#
# **Improve Operational Efficiency:**
#
# * Adjust hotel operations based on booking and demand trends to improve resource allocation. This includes optimizing staffing, room allocation, and special requests management to ensure smooth operations and reduce inefficiencies, especially during peak times.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

try:
    # Code that may raise an exception

    # mount google drive to load data from csv file
    from google.colab import drive
    drive.mount('/content/drive')

    # Read CSV file in google colab
    df_hotel_booking = pd.read_csv('Hotel Bookings.csv')

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

# Load first 5 rows of dataset using head
df_hotel_booking.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

# Find out dataset rows and columns count using shape
df_hotel_booking.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info

# Find out dataset information like non-null values count, datatype, datatype count and more
df_hotel_booking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

# Find out duplicate records in dataset using duplicated() method
len(df_hotel_booking[df_hotel_booking.duplicated()])
# Out:
# 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

# Find out missing values in dataset using isnull() method
print(df_hotel_booking.isnull().sum())
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Visualizing the missing values

# Visualizing the missing values using heatmap without color bar
sns.heatmap(df_hotel_booking.isnull(), cbar=False)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# * The dataset given is a dataset from booking.com platform, and we have to analysis booking processes to enhance customer satisfaction and optimize revenue.
#
# * The above dataset has 119390 rows and 32 columns. There are 3 columns with mising values (such as: country column with 488 missing values, agent column with 16340 missing values and company column with 112593 missing values) and 31994 duplicate values in the dataset.
#
# * This above dataset contains 4 float value columns, 16 interger value columns and 12 string value columns.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

# Find out columns name in the dataset
df_hotel_booking.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe

# Let's Know the statitical description of each column data
df_hotel_booking.describe(include='all')
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# * **Hotel:** H1 = Resort Hotel, H2 = City Hotel.
#
# * **is_canceled:** If the booking was cancelled (1) or not (0).
#
# * **lead_time:** Number of days that elapsed between the entering date of the booking into the PMS and the arrival date.
#
# * **arrival_date_year:** Year of arrival date.
#
# * **arrival_date_month:** Month of arrival date.
#
# * **arrival_date_week_number:** Week number of arrival date.
#
# * **arrival_date_day_of_month:** Day of arrival date.
#
# * **stays_in_weekend_nights:** Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel.
#
# * **stays_in_week_nights:** Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel.
#
# * **adults:** Number of adults.
#
# * **children:** Number of children.
#
# * **babies:** Number of babies.
#
# * **meal:** Kind of meal opted for.
#
# * **country:** Country code.
#
# * **market_segment:** Which segment the customer belongs to.
#
# * **distribution_channel:** How the customer accessed the stay-corporate booking/Direct/TA.TO
#
# * **is_repeated_guest:** Guest coming for first time or not.
#
# * **previous_cancellations:** Was there a cancellation before.
#
# * **previous_bookings_not_canceled:** Count of previous bookings.
#
# * **reserved_room_type:** Type of room reserved.
#
# * **assigned_room_type:** Type of room assinged.
#
# * **booking_changes:** Count of changes made to booking.
#
# * **deposit_type:** Deposit type.
#
# * **agent:** Booked through agent.
#
# * **days_in_waiting_list:** Number of days in waiting list.
#
# * **customer_type:** Type of customer.
#
# * **required_car_parking_spaces:** If car parking is required.
#
# * **total_of_special_requests:** Number of additional special requirement.
#
# * **reservation_status:** Reservation of status.
#
# * **reservation_status_date:** Date of specific status.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

try:
    # Code that may raise an exception

    # Find out the number of unique values in each column of the dataset
    for i in df_hotel_booking.columns.tolist():
      print("No. of unique values in ",i,"is",df_hotel_booking[i].nunique(),".")

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No. of unique values in  hotel is 2 .
# No. of unique values in  is_canceled is 2 .
# No. of unique values in  lead_time is 479 .
# No. of unique values in  arrival_date_year is 3 .
# No. of unique values in  arrival_date_month is 12 .
# No. of unique values in  arrival_date_week_number is 53 .
# No. of unique values in  arrival_date_day_of_month is 31 .
# No. of unique values in  stays_in_weekend_nights is 17 .
# No. of unique values in  stays_in_week_nights is 35 .
# No. of unique values in  adults is 14 .
# No. of unique values in  children is 5 .
# No. of unique values in  babies is 5 .
# No. of unique values in  meal is 5 .
# No. of unique values in  country is 177 .
# No. of unique values in  market_segment is 8 .
# No. of unique values in  distribution_channel is 5 .
# No. of unique values in  is_repeated_guest is 2 .
# No. of unique values in  previous_cancellations is 15 .
# No. of unique values in  previous_bookings_not_canceled is 73 .
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# Fill null values of missing values columns
try:
    # Code that may raise an exception

    # Make copy of dataframe
    df_hotel = df_hotel_booking.copy()

    # Fill missing values in 'company', 'agent' and in 'country' with 'Unknown'
    df_hotel['company'].fillna('Unknown', inplace=True)
    df_hotel['agent'].fillna('Unknown', inplace=True)
    df_hotel['country'].fillna('Unknown', inplace=True)

    # Filling missing values in the 'children' column with the mean value of the column
    mean_children = df_hotel['children'].mean()
    #print(mean_children)
    df_hotel['children'].fillna(mean_children, inplace=True)

    # Check null values are filled
    print(df_hotel.isnull().sum())

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
# Convert Data Types of the columns
try:
    # Code that may raise an exception

    # Check the data type of reservation_status_date column
    print("\nBefore: reservation_status_date column datatype \n", df_hotel['reservation_status_date'].dtype)

    # Convert 'reservation_status_date' column from object to datetime
    df_hotel['reservation_status_date'] = pd.to_datetime(df_hotel['reservation_status_date'])

   # Check the data type of reservation_status_date column
    print("\nAfter: reservation_status_date column datatype \n", df_hotel['reservation_status_date'].dtype)

    # Convert relevant categorical columns to 'category' data type for efficiency
    categorical_cols = [
        'hotel', 'meal', 'country', 'market_segment',
        'distribution_channel', 'customer_type',
        'reservation_status', 'reserved_room_type',
        'assigned_room_type', 'deposit_type'
    ]

    # Check the data type of categorical_cols columns list
    print("\nBefore: categorical_cols columns datatypes \n", df_hotel[categorical_cols].dtypes)

    # convert object datatype columns to category datatype
    df_hotel[categorical_cols] = df_hotel[categorical_cols].astype('category')

    # Check the data type of categorical_cols columns list
    print("\nAfter: categorical_cols columns datatypes \n", df_hotel[categorical_cols].dtypes)

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# Before: reservation_status_date column datatype
#  object
#
# After: reservation_status_date column datatype
#  datetime64[ns]
#
# Before: categorical_cols columns datatypes
#  hotel                   object
# meal                    object
# country                 object
# market_segment          object
# distribution_channel    object
# customer_type           object
# reservation_status      object
# reserved_room_type      object
# assigned_room_type      object
# deposit_type            object
# dtype: object
#
# After: categorical_cols columns datatypes
#  hotel                   category
# meal                    category
# country                 category
# market_segment          category
# distribution_channel    category
# customer_type           category
# reservation_status      category
# reserved_room_type      category
# assigned_room_type      category
# deposit_type            category
# dtype: object
# No exception occurred
# ...

# %%
# Create New columns from the given columns of the dataset
try:
    # Code that may raise an exception

    # Calculate total guests in each record
    df_hotel['total_guests'] = df_hotel['adults'] + df_hotel['children'] + df_hotel['babies']

    # Calculate total duration of stay in hotel
    df_hotel['total_stay'] = df_hotel['stays_in_weekend_nights'] + df_hotel['stays_in_week_nights']

    # Create a column for whether the booking was made by a repeated guest
    print("Before: is_repeated_guest datatype :: ", df_hotel['is_repeated_guest'].dtype)
    df_hotel['is_repeated_guest'] = df_hotel['is_repeated_guest'].astype(bool)
    print("After: is_repeated_guest datatype :: ", df_hotel['is_repeated_guest'].dtype)

    # Create a new column for the total number of bookings made by the guest
    df_hotel['total_bookings'] = df_hotel['previous_bookings_not_canceled'] + df_hotel['previous_cancellations']

    # print first five rows of new columns
    print(df_hotel[['total_guests', 'total_stay', 'is_repeated_guest', 'total_bookings']].head())

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# Before: is_repeated_guest datatype ::  int64
# After: is_repeated_guest datatype ::  bool
#    total_guests  total_stay  is_repeated_guest  total_bookings
# 0           2.0           0              False               0
# 1           2.0           0              False               0
# 2           1.0           1              False               0
# 3           1.0           1              False               0
# 4           2.0           2              False               0
# No exception occurred
# Execution of the try-except block is complete

# %%
# removed unrealistic or irrelevant entries
try:
    # Code that may raise an exception

    # Print the unrealistic entry count before removed
    print("Before:: how many rows in lead_time columns less than 0 is ::", len(df_hotel[df_hotel['lead_time'] < 0]))
    print("Before:: how many rows in total_stay columns less than 1 is ::", len(df_hotel[df_hotel['total_stay'] < 1]))

    # Remove rows with negative or zero lead time
    df_hotel = df_hotel[df_hotel['lead_time'] >= 0]

    # Remove rows with total stay less than 1
    df_hotel = df_hotel[df_hotel['total_stay'] >= 1]

    # Print the unrealistic entry count after removed
    print("After:: how many rows in lead_time columns less than 0 is ::", len(df_hotel[df_hotel['lead_time'] < 0]))
    print("After:: how many rows in total_stay columns less than 1 is ::", len(df_hotel[df_hotel['total_stay'] < 1]))

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# Before:: how many rows in lead_time columns less than 0 is :: 0
# Before:: how many rows in total_stay columns less than 1 is :: 715
# After:: how many rows in lead_time columns less than 0 is :: 0
# After:: how many rows in total_stay columns less than 1 is :: 0
# No exception occurred
# Execution of the try-except block is complete

# %%
# removed outliers
try:
    # Code that may raise an exception

    # Identify and remove outliers in ADR (Average Daily Rate)

    # Find out lower and upper quantiles
    q_low = df_hotel['adr'].quantile(0.01)
    q_high = df_hotel['adr'].quantile(0.99)
    print("lower quantile for outlier is :", q_low)
    print("upper quantile for outlier is :", q_high)

    # find out outliers in (Average Daily Rate)
    outilers = df_hotel[(df_hotel['adr'] < q_low) & (df_hotel['adr'] > q_high)]
    print("how many outliers are there in dataframe: ", len(outilers))

    # Remove outliers
    df_hotel = df_hotel[(df_hotel['adr'] > q_low) & (df_hotel['adr'] < q_high)]

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# lower quantile for outlier is : 0.0
# upper quantile for outlier is : 252.0
# how many outliers are there in dataframe:  0
# No exception occurred
# Execution of the try-except block is complete

# %%
# Extract insights through analysis
try:
    # Code that may raise an exception

    # Calculate cancellation rate by using average
    cancellation_rate = df_hotel['is_canceled'].mean() * 100
    print(f"Cancellation Rate: {cancellation_rate:.2f}%")

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# Cancellation Rate: 37.48%
# No exception occurred
# Execution of the try-except block is complete

# %%
# Extract insights through analyses
try:
    # Code that may raise an exception

    # Average daily rate (adr) by hotel type
    avg_adr = df_hotel.groupby('hotel')['adr'].mean().reset_index()
    print("Average Daily Rate (ADR) by Hotel Type:\n")
    print(avg_adr)

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# Average Daily Rate (ADR) by Hotel Type:
#
#           hotel         adr
# 0    City Hotel  106.183844
# 1  Resort Hotel   92.357455
# No exception occurred
# Execution of the try-except block is complete

# %%
# Extract insights through analyses
try:
    # Code that may raise an exception

    # Total bookings by market segment
    bookings_by_segment = df_hotel['market_segment'].value_counts().reset_index()
    # Change column names
    bookings_by_segment.columns = ['market_segment', 'total_bookings']
    print("Total Bookings by Market Segment:\n")
    print(bookings_by_segment)

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# Total Bookings by Market Segment:
#
#   market_segment  total_bookings
# 0      Online TA           55310
# 1  Offline TA/TO           23860
# 2         Groups           19529
# 3         Direct           12022
# 4      Corporate            5210
# 5       Aviation             231
# 6  Complementary              63
# 7      Undefined               2
# No exception occurred
# Execution of the try-except block is complete

# %%
# Extract insights through analyses
try:
    # Code that may raise an exception

    # Analyze the relationship between lead time and cancellation
    lead_time_cancellation = df_hotel.groupby('lead_time')['is_canceled'].mean().reset_index()
    print("Cancellation Rate by Lead Time:\n")
    print(lead_time_cancellation)

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# Cancellation Rate by Lead Time:
#
#      lead_time  is_canceled
# 0            0     0.066551
# 1            1     0.092496
# 2            2     0.104410
# 3            3     0.099942
# 4            4     0.099692
# ..         ...          ...
# 473        615     1.000000
# 474        622     1.000000
# 475        626     1.000000
# 476        629     1.000000
# 477        709     0.000000
#
# [478 rows x 2 columns]
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **Manipulations Performed**
#
# **Copy the Dataset:**
#
# * Copy the DataFrame into df_hotel DataFrame for data Wrangling.
#
# **Handling Missing Values:**
#
# * Identified missing values and filled in missing values for the 'company', 'agent' and 'country' columns with 'Unknown'. Missing values in 'children' column filled with mean value of 'children' column, then finally check is there any missing value left.
#
# **Correcting Data Types:**
#
# * Converted the 'reservation_status_date' column from 'object' to 'datetime' format for better analysis of data, then converted the [ 'hotel', 'meal', 'country', 'market_segment',
# 'distribution_channel', 'customer_type', 'reservation_status', 'reserved_room_type','assigned_room_type', 'deposit_type'] columns from 'object' to 'category' datatype for better and efficient analysis.
#
# **Feature Engineering:**
#
# * Created a new column 'total_guests' by summing 'adults', 'children', and 'babies'.
# * Calculated 'total_stay nights' by summing 'stays_in_weekend_nights' and 'stays_in_week_nights'.
# * Convetred 'is_repeated_guest' to boolean True and False value column.
# Calculated 'total_bookings' by summing 'previous_bookings_not_canceled' and 'previous_cancellations'.
#
# **Remove Unrealistic and Irrelevant entries:**
#
# * Removed the values from 'lead_time' column less than 0 because it is not an real entry.
# * Removed the values from 'total_stay' column less than 1 because it is unreal entry.
#
# **Remove Outliers:**
#
# * In Average Daily Rate column find out values less than 0.01 quantile and higher than 0.99 quantile, removed these values from dataset because these values are outliers.
#
#
#
# **Insights Found**
#
# **Cancellation Patterns:**
#
# * By analyzing the 'is_canceled' column, we can identify trends in cancellations, which can help in understanding customer behavior and improving booking strategies, in our dataset Cancellation Rate: 37.48%.
#
# **Guest Composition:**
#
# * The 'total_guests' feature provides insights into typical guest compositions, allowing for targeted marketing strategies (e.g., promotions for families or business travelers).
#
# **Stay Duration:**
#
# * The 'total_stay_nights' feature could reveal patterns in stay durations that are more common during different times of the year.
#
#
# **Geographical Trends:**
#
# * The 'country' feature can be analyzed to determine where most bookings originate, guiding targeted marketing campaigns.
#
#
# **Average daily rate (adr) by hotel type:**
#
#  * Average daily rate for "City Hotel" is 106.183844 and for "Resort Hotel" is 92.357455, so customers choose City Hotel rate is more than Resort Hotels rate.
#
#
#  **Total bookings by market segment:**
#
#  * Total booking by online market segment is double than offline market booking segment, so cutomers are preferring online bookings.
#
#
#  **Relationship between lead time and cancellation:**
#
#  * As lead time increases the cancellation also increases, so there is a positive relationship between lead time and cancellation.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# ::  Univariate Analysis (Single Variable)  ::

try:
    # Code that may raise an exception

    # Distribution of Average Daily Rate (ADR)

    # Figure size 8 on x-axis and 5 on y-axis
    plt.figure(figsize=(8, 5))

    # Use Histogram plot with 30 bins and kernel density plot
    sns.histplot(df_hotel['adr'], bins=30, kde=True)

    # Print the title, x-axis and y-axis labels
    plt.title('Distribution of Average Daily Rate (ADR)')
    plt.xlabel('Average Daily Rate (ADR)')
    plt.ylabel('Frequency')

    # show the plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The histogram with a smooth density line was selected to show how ADR (the average rate guests pay per night) is distributed. This chart makes it easy to see the most common room rates and any patterns or unusual rates in the data. The smooth line helps highlight these trends in the average daily rate.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Main Rate Range:** 40 to 150 price range that guests are willing to pay.
#
# * **Pricing Strategy Effectiveness:** The ADR distribution has multiple peaks (60, 70, 80), it could suggest that different pricing strategies (like promotions) are attracting different types of guests at varying rates.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** Knowing the most common ADR values helps the hotel set room rates in line with customer expectations. For example, if the typical ADR is high, the hotel might want to continue this pricing and offer premium packages to appeal to high-value guests. If most ADR values are lower, the hotel could consider offering upsells or premium services to increase revenue from those bookings.
#
# * **Possible Negative Impact:** Setting rates too high or too low can discourage bookings. If guests usually pay within a certain range, setting prices much higher could reduce demand, while setting prices too low could undervalue the hotel and attract guests who may not return. Keeping prices within the main range while occasionally testing premium options can help attract a good mix of guests.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# ::  Univariate Analysis (Single Variable)  ::

try:
    # Code that may raise an exception

    # Distribution of Lead Time

    # Figure size 8 on x-axis and 5 on y-axis
    plt.figure(figsize=(8, 5))

    # Use Histogram plot with 30 bins and kernel density plot
    sns.histplot(df_hotel['lead_time'], bins=30, kde=True)

    # Print the title, x-axis and y-axis labels
    plt.title('Distribution of Lead Time')
    plt.xlabel('Lead Time (Days)')
    plt.ylabel('Frequency')

    # show the plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram with a smooth line on top shows how many bookings happen at different lead times (days between booking and stay). This chart is great for spotting trends, like if most people book far in advance, close to the stay date, or somewhere in between. The smooth line helps make patterns clearer.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# If we see a big peak at short lead times, it suggests many guests are booking last minute, possibly looking for deals or flexibility.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** Knowing when guests usually book helps the hotel offer targeted deals. If most bookings are last-minute, the hotel could promote early booking discounts to encourage guests to book sooner, helping fill rooms ahead of time. If people generally book early, the hotel could reward early bookings with loyalty points or special rates.
#
#
# * **Possible Negative Impact:** Focusing too much on either last-minute or early bookings could limit the hotel’s flexibility. For example, raising prices too high for last-minute bookings could drive away last-minute guests, especially those expecting deals. A mix of early-bird and last-minute offers might be better for attracting a variety of guests.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# ::  Univariate Analysis (Single Variable)  ::

try:
    # Code that may raise an exception

    # Count of Reservations by Status

    # Figure size 8 on x-axis and 5 on y-axis
    plt.figure(figsize=(8, 5))

    # Plot the Count Plot of reservation_status
    sns.countplot(x='reservation_status', data=df_hotel)

    # Print the title, x-axis and y-axis labels
    plt.title('Count of Reservations by Status')
    plt.xlabel('Reservation Status')
    plt.ylabel('Count')

    # show the plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The count plot is a straightforward way to show the number of reservations by status (e.g., canceled, no-show, or check-out). This chart helps visualize how many reservations fall into each category, which provides a quick understanding of customer behavior related to booking commitments and cancellations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Cancellation Patterns:** The cancellations are 42000 (High), it may indicate issues like flexible cancellation policies or customers booking but not following through.
#
# * **No-Show Rate:** The very low no-show rate (2000) suggests that guests are not arriving even though they haven’t officially canceled. This could be due to a lack of penalties for no-shows or guests booking multiple hotels to keep their options open.
#
# * **Completed Reservations:** A high count (72000) of checked-out (completed) reservations suggests the success of the booking process and that guests are following through.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** Understanding reservation patterns helps the hotel manage occupancy and reduce revenue loss from cancellations and no-shows. For instance, if cancellations are high, the hotel could introduce non-refundable options for certain rate plans or incentivize commitment by offering discounts for confirmed reservations.
#
# * **Possible Negative Impact:** Overreacting to cancellations by making policies too strict might discourage future bookings, especially for guests who value flexibility. Maintaining a balance by offering flexible and non-flexible booking options can attract a wider range of customers while helping to manage cancellations.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# ::  Univariate Analysis (Single Variable)  ::

try:
    # Code that may raise an exception

    # Count of Bookings by Market Segment

    # Figure size 8 on x-axis and 5 on y-axis
    plt.figure(figsize=(8, 5))

    # Plot the Count Plot of market_segment
    sns.countplot(y='market_segment', data=df_hotel, order=df_hotel['market_segment'].value_counts().index)

    # Print the title, x-axis and y-axis labels
    plt.title('Count of Bookings by Market Segment')
    plt.ylabel('Market Segment')
    plt.xlabel('Count')

    # show the plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The count plot was chosen to visualize the number of bookings from each market segment (e.g., online TA, offline TA/TO, group). This helps the hotel understand which segments drive the most bookings, allowing them to tailor marketing strategies and resources to those segments. The horizontal layout improves readability when displaying segment names.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Top Segments:** The chart shows Online TA (60000), offline TA/TO (23000) and Group (20000) market segments bring in the most bookings.
#
# * **Segment-Specific Opportunities:** Segments with lower counts, like "Direct"(12000) or "Corporate (5000)" might be opportunities for growth. The hotel could create targeted promotions or partnerships to increase bookings in these segments.
#
# * **Resource Allocation:** Knowing which segments are most popular can help the hotel focus resources.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** Understanding the dominant market segments allows the hotel to create targeted strategies. For example, the "online TA" bookings are high, the hotel could invest in business-friendly services (e.g., faster Wi-Fi, meeting spaces) to enhance satisfaction and loyalty among business travelers. Similarly, popular segments can be rewarded with loyalty programs or special offers to boost repeat bookings.
#
#
# * **Possible Negative Impact:** Focusing too heavily on the top segments could lead to missed opportunities. If the hotel neglects smaller segments, such as groups or corporate bookings, it might miss out on diverse revenue streams. A balanced approach—while emphasizing the high-booking segments but not neglecting others—can help avoid over-reliance on a few segments and ensure steady, diversified revenue growth.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# ::  Univariate Analysis (Single Variable)  ::

try:
    # Code that may raise an exception

    # Number of Adults Distribution

    # Figure size 8 on x-axis and 5 on y-axis
    plt.figure(figsize=(8, 5))

    # Plot the Count Plot of adults
    sns.countplot(data=df_hotel, x='adults', palette="pastel")

    # Print the title, x-axis and y-axis labels
    plt.title('Distribution of Number of Adults per Booking')
    plt.xlabel('Number of Adults')
    plt.ylabel('Count')

    # show the plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot was chosen to show the distribution of the number of adults per booking. This is useful to understand the type of guests booking rooms. It helps the hotel identify whether guests typically book for solo stays, couples, or larger groups. The count plot makes it easy to see the most common number of adults per booking.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Solo and Couple Bookings:** The chart show that most bookings are for 1 or 2 adults, which is common for solo travelers or couples such as 20000 solo and 85000 couples.
#
# * **Family or Group Bookings:** Fewer (5000) bookings with larger numbers of adults could indicate that families or groups are less common, or perhaps that they tend to book different types of rooms.
#
# * **Booking Trends:** The couple guests are more common.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** Knowing the typical number of adults per booking helps the hotel better tailor its offerings. If most bookings are for 1 or 2 adults, the hotel might focus on optimizing small rooms or packages for couples or solo travelers. For larger groups or families, the hotel could create special family packages or multi-room deals to increase bookings from that segment.
#
# * **Possible Negative Impact:** If the hotel only focuses on bookings for 1 or 2 adults and neglects larger groups, it may miss out on an opportunity to increase group bookings, which could bring in higher revenue. A balanced approach to room offerings and promotions for both small and larger groups will ensure that the hotel attracts a wide variety of guests.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# ::  Univariate Analysis (Single Variable)  ::

try:
    # Code that may raise an exception

    # Total Special Requests

    # Figure size 8 on x-axis and 5 on y-axis
    plt.figure(figsize=(8, 5))

    # Plot the Count Plot of total_of_special_requests
    sns.countplot(data=df_hotel, x='total_of_special_requests', palette="mako")

    # Print the title, x-axis and y-axis labels
    plt.title('Distribution of Total Special Requests')
    plt.xlabel('Number of Special Requests')
    plt.ylabel('Count')

    # show the plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot was chosen to show the distribution of special requests made per booking. This chart helps the hotel understand the frequency and level of requests that guests make, such as room preferences, amenities, or service adjustments. By visualizing the range of special requests, the hotel can see if most guests have specific needs or if requests are relatively rare.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Common Request Levels:** The most bookings have 0 or 1 special request, it suggests that most guests have minimal needs.
#
# * **Resource Planning:** The many bookings have some special requests, additional staffing or systems may not be needed to meet demand.
#
# * **Enhanced Guest Experience:** By identifying popular requests, the hotel can proactively offer these services or options, potentially increasing guest satisfaction.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** Understanding special request patterns allows the hotel to optimize service delivery. If many guests make special requests, the hotel can prepare in advance, improving the guest experience. For example, popular requests (e.g., extra towels or certain room locations) could be offered as package options during booking, increasing guest satisfaction.
#
# * **Possible Negative Impact:** Over-promising on special requests without the resources to fulfill them could lead to dissatisfaction. If requests are frequent but the hotel is unable to consistently meet them, it may frustrate guests. Proper planning and realistic expectations are key to balancing request fulfillment with service quality.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# ::  Univariate Analysis (Single Variable)  ::

try:
    # Code that may raise an exception

    # Days in Waiting List Distribution

    # Figure size 10 on x-axis and 6 on y-axis
    plt.figure(figsize=(10, 6))

    # Plot the Histogram Plot of days_in_waiting_list
    sns.histplot(df_hotel['days_in_waiting_list'], kde=True, color="teal")

    # Print the title, x-axis and y-axis labels
    plt.title('Distribution of Days in Waiting List')
    plt.xlabel('Days in Waiting List')
    plt.ylabel('Frequency')

    # show the plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The histogram with a density line was chosen to show the distribution of the number of days guests spend on the waiting list before their booking is confirmed. This visualization helps identify patterns in waitlist times and highlights whether guests typically wait for a short or extended period. The histogram makes it easy to spot trends and any spikes in waiting times.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Typical Waiting Times:** The most common waiting periods is 0 to 20 days, showing the minimal wait times, it might mean that availability is generally high.
#
# * **Demand Peaks:** The clusters of 0 to 20 days wait times, it may indicate rooms are fully booked, pushing guests onto the waitlist.
#
# * **Guest Patience and Booking Urgency:** The wait times are very short 0 to 20 days, it may indicate that guests are unwilling to wait and might be canceling to book elsewhere. Longer waiting times like 40 to 90 days, could imply that guests are willing to wait, perhaps for popular dates or events.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** Understanding waitlist patterns allows the hotel to anticipate high-demand periods and consider adjusting pricing or promotions. During high-demand times, the hotel could offer incentives for confirmed bookings to avoid cancellations and maximize occupancy. For low-demand periods, they could adjust availability to reduce wait times and meet guest expectations faster.
#
# * **Possible Negative Impact:** If wait times are frequently long, guests might turn to competitors for immediate bookings, leading to lost revenue. The hotel should ensure waitlist times are reasonable, and if possible, offer flexible booking alternatives during high-demand periods. Excessive reliance on the waitlist without clear communication could frustrate guests, potentially impacting brand reputation.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# :: Bivariate Analysis (Two Variables) ::

# :: Categorical - Categorical Bivariate Analysis ::

try:
    # Code that may raise an exception

    # Cancellation Rate by Hotel Type

    # Figure size 8 on x-axis and 5 on y-axis
    plt.figure(figsize=(8, 5))

    # Plot the Bar Plot for hotel type and cancellation
    sns.barplot(x='hotel', y='is_canceled', data=df_hotel)

    # Print the title, x-axis and y-axis labels
    plt.title('Cancellation Rate by Hotel Type')
    plt.ylabel('Cancellation Rate')
    plt.xlabel('Hotel Type')

    # show the plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot was chosen to display the average cancellation rate for each hotel type. This chart helps easily compare how often bookings are canceled at each hotel type (e.g., resort vs. city hotels). By showing the cancellation rates visually, the hotel can see if one type has significantly more cancellations, which might indicate patterns or underlying issues.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Cancellation Rate Comparison:** The chart reveals city hotel type has a notably higher cancellation rate (43%) compare to resort hotel 26% cancellation rate.
#
# * **Impact of Booking Behavior:** A high cancellation rate for city hotel may suggest that customers are more flexible with those bookings or that factors like weather or seasonality impact guest decisions for city hotel.
#
# * **Policy Adjustments:** The cancellations are particularly high for city hotel type, stricter policies, incentives to confirm bookings, or changes to deposit requirements may be needed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** Understanding the cancellation rates by hotel type allows the hotel to address high cancellation rates specifically. For instance, the city hotels experience more cancellations, the hotel could introduce policies like non-refundable booking options or discounts for confirmed bookings. This insight can help stabilize revenue and reduce cancellations, leading to better occupancy management.
#
# * **Possible Negative Impact:** If cancellation policies become too restrictive in response to high rates, it could deter guests who value booking flexibility, potentially leading to a drop in bookings, especially for guests who are unsure about their travel plans. Therefore, balancing flexibility with policies that discourage cancellations is crucial to avoid alienating potential guests.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# :: Bivariate Analysis (Two Variables) ::

# :: Numerical - Categorical Bivariate Analysis ::

try:
    # Code that may raise an exception

    # Average Daily Rate (ADR) by Hotel Type

    # Figure size 8 on x-axis and 5 on y-axis
    plt.figure(figsize=(8, 5))

    # Plot the Bar Plot for hotel type and Average Daily Rate (ADR)
    sns.barplot(x='hotel', y='adr', data=df_hotel)

    # Print the title, x-axis and y-axis labels
    plt.title('Average Daily Rate (ADR) by Hotel Type')
    plt.ylabel('Average Daily Rate (ADR)')
    plt.xlabel('Hotel Type')

    # show the plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot was chosen to compare the Average Daily Rate (ADR) between different hotel types. This chart helps the hotel easily see if one type of hotel (e.g., city vs. resort) tends to command higher prices. By visualizing the ADR for each type, the hotel can quickly assess which type generates more revenue per room night, guiding pricing and marketing strategies.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **ADR Comparison by Hotel Type:** The city hotels have a higher ADR, it could reflect a premium pricing strategy or indicate that they are in high-demand locations.
#
# * **Revenue Optimization Opportunities:** A lower ADR for resort hotel type might suggest room for price adjustments, promotions, or bundling to optimize revenue. It could also reveal seasonal or demand-based pricing trends, allowing for targeted rate adjustments.
#
# * **Customer Willingness to Pay:** By identifying ADR differences, the hotel can gauge the price sensitivity of guests across hotel types. This helps in tailoring marketing messages and promotions to different customer segments, depending on the hotel type.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** Understanding the ADR differences allows the hotel to implement pricing strategies to maximize revenue. The city hotels have a higher ADR, the hotel can focus on promoting these rooms to high-spending guests or upscale vacationers. The resort hotels have a lower ADR, the hotel could introduce discounts for long stays or packages to increase occupancy.
#
# * **Possible Negative Impact:** Overly aggressive pricing increases for one hotel type could lead to fewer bookings if customers find the rates too high, especially if there are competing options. Balancing pricing to remain competitive while maximizing revenue is key to avoid driving customers to alternatives.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# :: Bivariate Analysis (Two Variables) ::

# :: Numerical - Categorical Bivariate Analysis ::

try:
    # Code that may raise an exception

    # Lead Time vs. Cancellation Rate

    # Figure size 8 on x-axis and 5 on y-axis
    plt.figure(figsize=(8, 5))

    # Plot box plot for is_canceled and lead_time
    sns.boxplot(x='is_canceled', y='lead_time', data=df_hotel)

    # Print the title, x-axis and y-axis labels
    plt.title('Lead Time by Cancellation Status')
    plt.xlabel('Cancellation Status')
    plt.ylabel('Lead Time (Days)')

    # show the plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot was chosen to show the relationship between lead time and cancellation status. The box plot is effective in displaying the distribution of lead times for bookings that were canceled versus those that were not, highlighting median values, ranges, and any outliers. This chart provides insight into whether longer lead times are associated with a higher likelihood of cancellation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Cancellation and Lead Time Relationship:** The chart show that bookings with longer lead times have higher cancellation rates, as people often book in advance and may change plans later. Shorter lead times may correlate with fewer cancellations, suggesting that people with immediate plans are more likely to follow through.
#
# * **Risk Management for Cancellations:** Longer lead times associated with high cancellations could imply a need for better booking policies (e.g., stricter cancellation terms for long lead times) to manage risks associated with advance bookings.
#
# * **Predictive Insight:** The lead time distribution could help the hotel predict which bookings are at higher risk of cancellation, potentially guiding policies or customer engagement strategies to reduce cancellations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** By understanding the connection between lead time and cancellation risk, the hotel can introduce strategies to reduce cancellations. For instance, they could require deposits or offer flexible date options for long lead-time bookings to retain customers. This can improve revenue reliability and help in more accurate forecasting.
#
# * **Possible Negative Impact:** If the hotel implements too-strict policies (e.g., non-refundable deposits on long lead-time bookings), it might deter guests from booking early, reducing the number of bookings. A balanced approach is essential to encourage early bookings while managing cancellations.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# :: Bivariate Analysis (Two Variables) ::

# ::  Numerical - Numerical Bivariate Analysis  ::

try:
    # Code that may raise an exception

    # ADR vs. Number of Special Requests

    # Figure size 8 on x-axis and 5 on y-axis
    plt.figure(figsize=(8, 5))

    # Plot scatter plot for adr and total_of_special_requests
    sns.scatterplot(x='adr', y='total_of_special_requests', data=df_hotel)

    # Print the title, x-axis and y-axis labels
    plt.title('ADR vs. Total Special Requests')
    plt.xlabel('Average Daily Rate (ADR)')
    plt.ylabel('Total Special Requests')

    # show the plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot was chosen to explore the relationship between the Average Daily Rate (ADR) and the number of special requests. This chart can providing insight into customer behavior at different price points. Scatter plots are effective in visualizing correlations, trends, or clusters in two numerical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **ADR and Request Correlation:** There is a positive correlation, guests paying a higher ADR (between 50 to 250) may be more likely to make special requests, indicating that higher-paying guests may expect additional services.
#
# * **Customer Expectations by Price Point:** The chart show clusters of low-ADR (between 0 to 50) bookings with few requests, potentially indicating that budget-conscious guests have fewer special demands.
#
# * **Service Optimization:** The hotel could identify the types of requests more frequently associated with high ADR, helping to improve service or offer packages that cater to high-paying customers preferences.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** Understanding that higher ADR bookings may come with more special requests allows the hotel to tailor services or packages to match customer expectations at different price points. For instance, if high-ADR guests consistently make special requests, offering premium or customized packages could increase customer satisfaction and justify higher rates.
#
# * **Possible Negative Impact:** If too many resources are devoted to fulfilling special requests without adequate compensation, it could strain operations, especially if these requests are labor-intensive. The hotel should ensure that the cost of fulfilling special requests aligns with the ADR to maintain profitability.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# :: Bivariate Analysis (Two Variables) ::

# :: Numerical - Categorical Bivariate Analysis ::

try:
    # Code that may raise an exception

    # Length of Stay by Hotel Type

    # Combine total stay by adding stays_in_weekend_nights and stays_in_week_nights
    df_hotel['length_of_stay'] = df_hotel['stays_in_weekend_nights'] + df_hotel['stays_in_week_nights']

    # Figure size 8 on x-axis and 5 on y-axis
    plt.figure(figsize=(8, 5))

    # Plot box plot for hotel and length_of_stay
    sns.boxplot(x='hotel', y='length_of_stay', data=df_hotel)

    # Print the title, x-axis and y-axis labels
    plt.title('Length of Stay by Hotel Type')
    plt.xlabel('Hotel Type')
    plt.ylabel('Length of Stay (Nights)')

    # show the plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot was chosen to compare the length of stay across different hotel types. This chart is ideal for showing the distribution of stay durations for each hotel type, including median values, variability, and outliers. It allows the hotel to see if certain hotel types (e.g., resort vs. city hotels) attract guests for longer stays, which is valuable for understanding guest behavior and planning resource allocation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Stay Duration Patterns by Hotel Type:** The guests at resort hotels might stay longer, while city hotels could have shorter, business-related stays.
#
# * **Resource and Staffing Needs:** Longer stays may require different staffing or resource management than shorter stays, such as housekeeping frequency or amenities provided. This insight can help the hotel plan operations efficiently.
#
# * **Marketing Strategies:** The resort hotel attracts longer stays, the hotel can tailor marketing efforts for longer stays at resort hotel, potentially offering discounts or packages to attract similar guests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** By understanding typical stay durations, the hotel can optimize staffing, offer targeted promotions, and anticipate resource demands more accurately. For example, if resort hotels generally see longer stays, offering multi-day discounts or enhanced amenities could increase satisfaction and booking frequency.
#
# * **Possible Negative Impact:** Misinterpreting the data and applying the same strategies across all hotel types could backfire. For example, trying to attract long-stay guests at a city hotel might not be effective if most city guests prefer shorter stays, potentially leading to lower occupancy rates.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# :: Bivariate Analysis (Two Variables) ::

# ::  Numerical - Categorical Bivariate Analysis  ::

try:
    # Code that may raise an exception

    # Lead Time vs. Hotel Type

    # Figure size 8 on x-axis and 5 on y-axis
    plt.figure(figsize=(8, 5))

    # Plot box plot for hotel and lead_time
    sns.boxplot(data=df_hotel, x='hotel', y='lead_time', palette="Blues")

    # Print the title, x-axis and y-axis labels
    plt.title('Lead Time by Hotel Type')
    plt.xlabel('Hotel Type')
    plt.ylabel('Lead Time (Days)')

    # show the plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot was selected to compare the lead time between different hotel types. This chart provides an effective way to display the distribution of lead times (i.e., the number of days between booking and arrival) for each hotel type, highlighting the median, spread, and any outliers. It can reveal if one hotel type tends to attract more advance bookings than the other, which is helpful for planning and forecasting.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Advance Booking Patterns by Hotel Type:** The chart show that city hotel type has a longer average lead time, while the resort hotel type has shorter lead times. This suggests that city hotels may attract guests who plan well in advance, such as  business travelers, whereas resort hotels may have more last-minute bookings, possibly from vacationers.
#
# * **Revenue Forecasting and Pricing:** Understanding the lead time differences allows the hotel to make more accurate revenue forecasts and adjust pricing based on demand. For example, a longer lead time for city hotels could lead to early-bird discounts to encourage even earlier bookings or tiered pricing as check-in dates approach.
#
# * **Marketing and Target Audience:** The resort hotel type sees consistently shorter lead times, marketing campaigns could be designed to target last-minute bookers. Conversely, the city hotel could attract advance planners with early-booking promotions if longer lead times are typical.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** Understanding lead time patterns by hotel type helps in optimizing marketing strategies, pricing, and resource planning. By knowing when each type of hotel is likely to be booked, the hotel can use tiered pricing to fill rooms, maximize revenue, and offer targeted promotions to increase occupancy.
#
# * **Possible Negative Impact:** If lead times are misinterpreted, the hotel might invest in promotions or discounts that don’t align with guest booking habits, leading to lower revenue. For example, offering last-minute discounts for resort hotels may not be effective if most guests book far in advance, possibly reducing perceived value.

# %% [markdown]
# #### Chart - 14

# %%
# Chart - 14 visualization code

# :: Bivariate Analysis (Two Variables) ::

# ::  Numerical - Numerical Bivariate Analysis  ::

try:
    # Code that may raise an exception

    # Previous Cancellations vs. Lead Time

    # Figure size 10 on x-axis and 6 on y-axis
    plt.figure(figsize=(10, 6))

    # Plot scatter plot for previous_cancellations and lead_time
    sns.scatterplot(data=df_hotel, x='previous_cancellations', y='lead_time', hue='hotel', palette="magma", alpha=0.6)

    # Print the title, x-axis and y-axis labels
    plt.title('Previous Cancellations vs. Lead Time')
    plt.xlabel('Previous Cancellations')
    plt.ylabel('Lead Time (Days)')

    # Add legend to plot
    plt.legend(title="Hotel Type")

    # show the plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot was chosen to examine the relationship between previous cancellations and lead time, with different colors representing hotel types. This visualization is suitable for exploring patterns between two numerical variables, especially when using hue to distinguish between categories (hotel types). It helps determine if a longer lead time correlates with a history of cancellations and whether this varies by hotel type, which is relevant for understanding guest behavior.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Cancellation Patterns and Lead Time:** The scatter plot show that high lead times correlate with frequent cancellations, it suggests that guests booking far in advance are more likely to cancel.
#
# * **Differences by Hotel Type:** By using color to represent hotel types, the chart reveal that city hotel type experiences more cancellations at higher lead times compared to the resort hotel type. This information could indicate different guest behaviors or booking habits depending on the type of hotel.
#
# * **Risk Assessment for Cancellations:** Recognizing patterns in lead time and cancellations helps the hotel better predict which reservations are at risk of cancellation, enabling proactive measures like flexible cancellation policies or targeted follow-ups for high-risk bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** Understanding the relationship between lead time and previous cancellations allows the hotel to implement targeted cancellation policies. For instance, the hotel could offer incentives to guests with long lead times to confirm their booking or adjust deposit requirements to reduce last-minute cancellations, thereby improving revenue stability.
#
# * **Possible Negative Impact:** If cancellation policies or requirements are too strict based on lead time, it could deter potential guests who need flexible options, especially for resort stays that are often planned well in advance. Misinterpreting data trends may lead to lost bookings if policies aren’t balanced with guest expectations.

# %% [markdown]
# #### Chart - 15

# %%
# Chart - 15 visualization code

# :: Bivariate Analysis (Two Variables) ::

# ::  Categorical - Categorical Bivariate Analysis  ::

try:
    # Code that may raise an exception

    # Customer Type vs. Cancellation Rate

    # Figure size 10 on x-axis and 6 on y-axis
    plt.figure(figsize=(10, 6))

    # Plot bar plot for customer_type and is_canceled
    sns.barplot(data=df_hotel, x='customer_type', y='is_canceled', palette="coolwarm")

    # Print the title, x-axis and y-axis labels
    plt.title('Cancellation Rate by Customer Type')
    plt.xlabel('Customer Type')
    plt.ylabel('Cancellation Rate')

    # show the plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot was chosen to compare cancellation rates across different customer types. This type of chart makes it easy to see differences in cancellation rates for each category, which is helpful for understanding which types of customers are more likely to cancel their bookings. This insight is valuable for planning retention strategies or creating tailored cancellation policies based on customer behavior.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Cancellation Behavior by Customer Type:** The bar plot shows differences in cancellation rates between customer types, such as "Transient" (individual bookings) vs. "Group" or "Contract" bookings. The transient guests show a higher cancellation rate, the hotel may want to focus on retention strategies for this group.
#
# * **Targeted Policies or Incentives:** Understanding which customer types cancel more frequently can guide the hotel in creating tailored incentives or policies to reduce cancellations. The particular customer type, like "Transient," has a high cancellation rate, the hotel might offer discounts or other perks to encourage them to keep their reservations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** By recognizing which customer types are prone to cancellations, the hotel can proactively address these behaviors. This may include offering targeted incentives to high-cancellation customer types, applying stricter cancellation policies to certain groups, or focusing on retention strategies for transient customers. These actions can reduce revenue loss due to cancellations and improve overall occupancy rates.
#
# * **Potential Negative Impact:** If the hotel enforces overly strict cancellation policies based on customer type, it might discourage certain customers from booking, especially if they value flexibility (like transient guests). Such policies could potentially lead to negative growth if they conflict with customer expectations.

# %% [markdown]
# #### Chart - 16

# %%
# Chart - 16 visualization code

# :: Bivariate Analysis (Two Variables) ::

# :: Numerical - Numerical Bivariate Analysis ::

try:
    # Code that may raise an exception

    # Scatter Plot with Hue for Hotel Type

    # Figure size 8 on x-axis and 5 on y-axis
    plt.figure(figsize=(8, 5))

    # Plot Scatter plot for adr and lead_time with hotel in hue
    sns.scatterplot(x='adr', y='lead_time', hue='hotel', data=df_hotel, alpha=0.6, palette="viridis")

    # Print the title, x-axis and y-axis labels
    plt.title('ADR vs. Lead Time by Hotel Type')
    plt.xlabel('Average Daily Rate (ADR)')
    plt.ylabel('Lead Time (Days)')

    # show the plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This scatter plot was selected to explore the relationship between Average Daily Rate (ADR) and Lead Time (days from booking to check-in), with hotel type as a hue. The scatter plot is ideal for visualizing relationships between two continuous variables (ADR and lead time) and allows us to observe trends or clusters by hotel type. The use of color to differentiate hotel types helps highlight any differences in booking behaviors between city and resort hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Booking and Pricing Patterns by Hotel Type:** The chart show that city hotel type typically has a higher ADR at shorter lead times, indicating that guests pay less for advance bookings. Conversely, resort hotels have a wide spread in lead time at varying ADRs, suggesting a mix of advance and last-minute bookings.
#
# * **Revenue Management Opportunities:** The relationship between ADR and lead time can guide pricing strategies. The higher ADRs are associated with shorter lead times, the hotel may consider offering discounts for last-minute bookings to fill vacancies. Alternatively, The ADR varying with wide lead time for resort hotels, targeted pricing adjustments could help maximize revenue.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** Understanding how ADR and lead time vary by hotel type can improve revenue management. The hotel can adjust pricing and marketing strategies to encourage advance bookings or fill rooms closer to check-in dates, increasing overall occupancy. For example, if high ADRs are more common with long lead times in resort hotels, the hotel could promote early booking deals for these guests.
#
# * **Possible Negative Impact:** If pricing strategies based on lead time aren’t balanced, they could reduce the perceived value of bookings. For example, if prices are heavily discounted at the last minute, guests who book early might feel disadvantaged, impacting guest satisfaction. Additionally, if last-minute discounts become predictable, guests may delay booking to get better rates, affecting the hotel's advance booking rate and revenue predictability.

# %% [markdown]
# #### Chart - 17

# %%
# Chart - 17 visualization code

# :: Bivariate Analysis (Two Variables) ::

# :: Numerical - Categorical Bivariate Analysis ::

try:
    # Code that may raise an exception

    # Boxplot of ADR by Customer Type

    # Figure size 10 on x-axis and 6 on y-axis
    plt.figure(figsize=(10, 6))

    # Plot Box plot for adr and customer_type
    sns.boxplot(x='customer_type', y='adr', data=df_hotel, palette="Blues")

    # Print the title, x-axis and y-axis labels
    plt.title('ADR by Customer Type')
    plt.xlabel('Customer Type')
    plt.ylabel('Average Daily Rate (ADR)')

    # show the plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot was selected to display the distribution of ADR (Average Daily Rate) across different customer types. Box plots are effective for showing median values, range, and outliers, making it easy to compare the ADR spread for each customer type. This allows us to quickly identify differences in spending patterns, such as whether transient guests (individuals) or contract tend to have higher average rates.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Differences in ADR by Customer Type:** The box plot may reveal that certain customer types, like "Transient" guests, have a wider range in ADR, while others, like "Contract" bookings, might have a more stable or lower ADR. This insight could indicate that transient customers are willing to pay a premium, whereas contract or group bookings are at a negotiated, lower rate.
#
# * **Revenue Opportunities for High-ADR Customer Types:** Knowing which customer types are associated with higher ADRs can guide revenue management decisions. For example, if transient guests consistently yield higher rates, the hotel might focus on marketing and tailored promotions for these guests to maximize revenue.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** These insights allow the hotel to develop targeted strategies based on customer type. The transient customers generally pay higher rates, the hotel can tailor its offerings to attract more of these guests, enhancing revenue. For lower-ADR customer types, like "Group" the hotel could consider renegotiating contract terms or offering upsell options to increase revenue.
#
# * **Possible Negative Impact:** If the hotel focuses too heavily on high-ADR customer types and neglects others, it may lose a steady revenue stream from group or contract bookings, which typically provide occupancy stability. Additionally, if group or contract clients perceive unfair treatment compared to transient guests, this could impact long-term partnerships and brand loyalty.

# %% [markdown]
# #### Chart - 18

# %%
# Chart - 18 visualization code

# :: Multivariate Analysis (More than two variables) ::

try:
    # Code that may raise an exception

    # Heatmap of Average Daily Rate and Cancellation Rate by Month

    # Get month name in month column
    df_hotel['month'] = df_hotel['reservation_status_date'].dt.month_name()

    # Group by month then calculate mean of adr and is_canceled by using aggregate function
    monthly_stats = df_hotel.groupby('month').agg({'adr': 'mean', 'is_canceled': 'mean'}).reset_index()

    # Figure size 12 on x-axis and 6 on y-axis
    plt.figure(figsize=(12, 6))

    # Heat Map on pivot table
    sns.heatmap(monthly_stats.pivot(index = 'month', columns = 'adr', values = 'is_canceled'), cmap='YlGnBu', annot=True)

    # Print the title
    plt.title('Average Daily Rate and Cancellation Rate by Month')

    # show the plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The heatmap was chosen to explore the relationship between Average Daily Rate (ADR) and cancellation rate over different months. Heatmaps are effective for highlighting patterns in multi-dimensional data, making it easy to spot months with high or low ADRs and see how these correlate with cancellation rates. By using color to show variation, the chart offers a quick visual summary of how ADR and cancellation rates fluctuate by month.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Seasonal Trends in ADR and Cancellations:** The heatmap may reveal that some months (e.g., summer months) have higher ADRs due to increased demand, while others (e.g., winter months) may have lower ADRs. Similarly, certain months may show higher cancellation rates, potentially due to off-peak seasons, economic factors, or weather-related issues.
#
# * **High ADR vs. Cancellation Correlation:** Months with high ADRs might also show low cancellation rates, suggesting that customers may be more likely to cancel when rates are low. Conversely, lower ADRs might show higher cancellation rates.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** Understanding monthly patterns in ADR and cancellation rates allows the hotel to tailor its strategies seasonally. During high-demand months, the hotel can consider implementing stricter cancellation policies to reduce the impact of cancellations. In low-demand months, the hotel can offer promotions or incentives to improve occupancy without risking high cancellation rates. This strategic approach can help the hotel stabilize revenue and optimize occupancy.
#
# * **Possible Negative Impact:** If the hotel increases rates too much during high-demand months or enforces overly strict cancellation policies, it may deter guests, leading to lost bookings or reduced guest loyalty. Alternatively, reliance on deep discounts during low-demand months could undervalue the brand and reduce profitability in the long term.

# %% [markdown]
# #### Chart - 19

# %%
# Chart - 19 visualization code

# :: Multivariate Analysis (More than two variables) ::

try:
    # Code that may raise an exception

    # Count Plot of Reservations by Month and Hotel Type

    # Get month name from reservation_status_date into 'month' column
    df_hotel['month'] = df_hotel['reservation_status_date'].dt.month_name()

    # Figure size 12 on x-axis and 6 on y-axis
    plt.figure(figsize=(12, 6))

    # Plot Count plot for month and hotel
    sns.countplot(x='month', hue='hotel', data=df_hotel)

    # Print the title, x-axis and y-axis labels
    plt.title('Count of Reservations by Month and Hotel Type')
    plt.ylabel('Count of Reservations')
    plt.xticks(rotation=45)

    # show the plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The count plot was chosen to display the number of reservations for each month, broken down by hotel type. Count plots are ideal for categorical data, making it easy to observe the seasonal booking patterns for each hotel type (e.g., city hotels vs. resort hotels) and determine which months attract the most reservations. The chart allows us to visually assess the demand trends across different hotel types throughout the year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Seasonal Demand Differences:** The chart show distinct peaks in reservations during certain months, indicating high demand periods, such as monsoon or holiday seasons. For example, if city hotels see a peak in monsoon months, it suggests a seasonal preference for monsoon enjoyment.
#
# * **Comparison of Hotel Types by Month:** It may reveal that certain months consistently attract more reservations for one hotel type over the other. For instance, city hotels might maintain higher reservations throughout the year due to business travel, while resort hotels might see seasonal surges tied to vacation periods.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** These insights can help the hotel optimize staffing, room pricing, and promotional efforts based on expected demand by month. The city and resort hotels see steady bookings year-round, this could guide revenue management decisions to maintain competitive pricing and capitalize on consistent occupancy.
#
# * **Possible Negative Impact:** The the hotel relies solely on seasonal peaks without diversifying demand (e.g., attracting off-season bookings for resort and city hotels), it may face inconsistent revenue streams.

# %% [markdown]
# #### Chart - 20

# %%
# Chart - 20 visualization code

# :: Multivariate Analysis (More than two variables) ::

try:
    # Code that may raise an exception

    # Box Plot: Total Special Requests by Hotel Type and Cancellation Status

    # Figure size 10 on x-axis and 6 on y-axis
    plt.figure(figsize=(10, 6))

    # Box plot for hotel, total_of_special_requests, is_canceled
    sns.boxplot(data=df_hotel, x='hotel', y='total_of_special_requests', hue='is_canceled', palette="Set1")

    # Print the title, x-axis and y-axis labels
    plt.title('Total Special Requests by Hotel Type and Cancellation Status')
    plt.xlabel('Hotel Type')
    plt.ylabel('Total Special Requests')

    # Added legend with title and lables
    plt.legend(title="Canceled", labels=["Not Canceled", "Canceled"])

    # show the plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The box plot was chosen to show the distribution of special requests by hotel type and cancellation status. Box plots are effective for displaying the spread and central tendency of numerical data, making it easy to observe patterns and compare the variation in special requests for each hotel type among guests who canceled and those who did not. This approach provides insights into whether the number of special requests correlates with cancellations, which can help hotels understand guest preferences and potential issues.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Special Requests and Cancellations:** The canceled bookings show consistently high special request counts, it might suggest that guests with more special requests are more likely to cancel, potentially due to unmet requests or complex arrangements.
#
# * **Differences by Hotel Type:** Comparing city hotels and resort hotels may reveal different distributions of special requests. For instance, the city and resort hotels have more special requests overall, it might indicate more to leisure guests with specific needs.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** This information can help hotel management better accommodate high-request guests and identify trends in cancellations linked to unmet special requests. By improving processes to fulfill these requests, the hotel could reduce cancellations, improve guest satisfaction, and foster repeat bookings. Additionally, the hotel could proactively reach out to high-request guests before arrival to confirm arrangements and prevent cancellations.
#
# * **Possible Negative Impact:** Over-prioritizing special requests without balancing costs could strain resources or increase operating expenses, particularly if these requests do not significantly reduce cancellations. Furthermore, if the hotel focuses only on catering to high-request guests without considering cost-efficiency, it may inadvertently reduce profitability.

# %% [markdown]
# #### Chart - 21 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

try:
    # Code that may raise an exception

    # Correlation Heatmap between all columns

    # Figure size 14 on x-axis and 10 on y-axis
    plt.figure(figsize=(14, 10))

    # Drop non-numeric columns
    numeric_df = df_hotel.select_dtypes(include='number')

    # Calculate correlation matrix
    correlation = numeric_df.corr()

    # Plot heat map on all correlation data
    sns.heatmap(correlation, annot=True, fmt='.2f', cmap='coolwarm', square=True)

    # Print Title
    plt.title('Correlation Heatmap')

    # Show plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The correlation heatmap was chosen to illustrate the relationships among various numerical columns in the dataset. Heatmaps provide a clear, color-coded way to examine which pairs of variables are positively or negatively correlated. This helps identify potential patterns or relationships between variables that could inform business strategies, especially regarding factors that may contribute to cancellations, lead time, or customer requests.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Key Correlations:** The heatmap allows us to see which variables have strong positive or negative correlations. For instance, the lead time has a significant positive correlation with cancellation rate, this may suggest that the longer the booking lead time, the higher the chance of cancellation.
#
# * **Weak or Insignificant Correlations:** Some variables may have very low correlation values with others, indicating little to no linear relationship. This can help narrow down key factors that truly influence certain business outcomes, such as identifying variables unrelated to cancellation or booking frequency.
#
# * **Operational Insights:** Relationships between factors like ADR (Average Daily Rate) and lead time or special requests can reveal trends in pricing and customer needs, informing revenue management and service improvement strategies.

# %% [markdown]
# #### Chart - 22 - Pair Plot

# %%
# Pair Plot visualization code

try:
    # Code that may raise an exception

    # Pair Plot

    # Plot Pair with three columns and hue is_cancled
    sns.pairplot(df_hotel[['adr', 'lead_time', 'total_of_special_requests', 'is_canceled']], hue='is_canceled')

    # Print Title
    plt.title('Pairplot of Key Variables')

    # Show plot
    plt.show()

except Exception as e:
    # Handle any type of exception
    print("An error occurred:", e)
else:
    # Run if no exception occurred
    print("No exception occurred")
finally:
    # Always executed, whether an exception occurred or not
    print("Execution of the try-except block is complete")
# Out:
# No exception occurred
# Execution of the try-except block is complete

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pairplot was chosen because it helps explore the relationships between several key numerical variables (e.g., ADR (Average Daily Rate), lead time, and total special requests) with respect to cancellation status. Pairplots provide scatterplots for each variable against the others and indicate distribution patterns, making it easier to observe correlations and trends among these variables and see if any patterns differ between canceled and non-canceled bookings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Lead Time and ADR:** The pairplot shows that all lead times evenly distirbuted across ADR values for not canceled bookings.
#
# * **Special Requests and Cancellations:** The chart shows that guests with specific requests are more likely to complete their stay. more the special request more they stay.
#
# * **Distribution Patterns:** High ADR has low cancellation and high lead time has more cancellation rate.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# * **Optimize Pricing & Lead Time:** Adjust prices based on lead time and seasonality. Offer incentives for early bookings and increase prices for last-minute reservations to reduce cancellations and boost revenue.
#
# * **Target Marketing to Customer Segments:** Focus on loyal customers and specific market segments. Tailor promotions to each group for better conversion rates and reduced cancellations.
#
# * **Refine Cancellation Policies:** Implement flexible cancellation policies based on lead time and booking behavior. Offer non-refundable options for long-lead bookings to reduce cancellations.
#
# * **Manage ADR by Customer & Hotel Type:** Adjust Average Daily Rates (ADR) according to customer type and hotel type. Ensure competitive pricing while offering special packages for high-ADR guests.
#
# * **Seasonal Adjustments:** Analyze booking patterns by month and adjust inventory, rates, and marketing strategies accordingly. Focus on high-demand months and improve occupancy during low seasons.
#
# * **Engage Guests with High Lead Time:** Maintain communication with guests who book far in advance, offering reminders and special deals to keep their commitment.
#
# * **Enhance Guest Experience:** Meet special requests to boost guest satisfaction and loyalty. Personalize the guest experience for repeat visitors to encourage future bookings.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# * **Cancellation Reduction:** The analysis reveals that cancellations are closely linked to lead time and customer type. Implementing strategies such as non-refundable options for longer lead times and targeting loyal customers with personalized offers could reduce cancellation rates.
#
# * **Revenue Optimization:** By understanding the relationship between Average Daily Rate (ADR) and factors like booking type, customer segment, and hotel type, the business can adjust pricing strategies to increase revenue while maintaining competitiveness. Seasonal pricing adjustments can also help optimize ADR based on demand trends.
#
# * **Customer Segmentation:** Identifying and targeting specific customer segments and tailoring marketing and pricing strategies accordingly can improve conversion rates and customer satisfaction.
#
# * **Operational Efficiency:** The data suggests that hotels should consider offering packages and special requests that enhance the guest experience. This can drive loyalty and increase the likelihood of repeat bookings, especially in high-demand months.
#
# * **Booking Behavior & Market Insights:** Understanding booking patterns and adjusting resources and marketing strategies for peak periods can help balance demand and capacity effectively. For instance, booking patterns by market segment and hotel type can help optimize inventory and staff allocation.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
